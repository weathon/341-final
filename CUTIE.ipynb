# %% [markdown]
# <a href="https://colab.research.google.com/github/weathon/341-final/blob/main/CUTIE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
from openai import OpenAI
from google.colab import userdata
import requests
import pylab


client = OpenAI(api_key=userdata.get('key'))
last_prompts = []
for i in range(10):
  response = client.images.generate(
    model="dall-e-3",
    prompt="A very cute cat eating a cheesebuger, photo style. Your last prompt were ' " +str(last_prompts)+" ' but they were not cute enough. I want much cuter than those. ",
    size="1024x1024",
    quality="standard",
    n=1,
  )

  image_url = response.data[0].url
  print(image_url)
  last_prompts.append(response.data[0].revised_prompt)

  img_data = requests.get(image_url).content
  with open(f'image{i}.jpg', 'wb') as handler:
    handler.write(img_data)

  pylab.imshow(pylab.imread(f'image{i}.jpg'))
  pylab.show()
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-e5EImirvW6uwXmqoHccD1oT3/user-mdxGm7HSEajVtiHWLV0P3ZCJ/img-UoAt5qRjsgp2gs1gC2DIwvCn.png?st=2023-11-30T07%3A11%3A02Z&se=2023-11-30T09%3A11%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-29T19%3A08%3A37Z&ske=2023-11-30T19%3A08%3A37Z&sks=b&skv=2021-08-06&sig=E9yCnDqJYHM608zWE8uGsZ8K6lcN/8FmCetspp8YkD8%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-e5EImirvW6uwXmqoHccD1oT3/user-mdxGm7HSEajVtiHWLV0P3ZCJ/img-ZrdPYo3BeLEdVp6Kdc3hcKg2.png?st=2023-11-30T07%3A11%3A18Z&se=2023-11-30T09%3A11%3A18Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-29T19%3A06%3A42Z&ske=2023-11-30T19%3A06%3A42Z&sks=b&skv=2021-08-06&sig=CE1o6EqHf9rKnBEkswt%2BuK6CElotTIh/MvhjQVMbKhY%3D
# ...

# %%
from openai import OpenAI
from google.colab import userdata
import requests
import pylab


client = OpenAI(api_key=userdata.get('key'))
last_prompts = []
for i in range(10):
  response = client.images.generate(
    model="dall-e-2",
    prompt="A very cute cat eating a cheesebuger, photo style. Your last prompt were ' " +str(last_prompts)+" ' but they were not cute enough. I want much cuter than those. ",
    size="1024x1024",
    quality="standard",
    n=1,
  )

  image_url = response.data[0].url
  print(image_url)
  last_prompts.append(response.data[0].revised_prompt)

  img_data = requests.get(image_url).content
  with open(f'image{i}.jpg', 'wb') as handler:
    handler.write(img_data)

  pylab.imshow(pylab.imread(f'image{i}.jpg'))
  pylab.show()
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-e5EImirvW6uwXmqoHccD1oT3/user-mdxGm7HSEajVtiHWLV0P3ZCJ/img-WwusJb83ZaOYES2CuTQLk5DO.png?st=2023-11-30T07%3A12%3A35Z&se=2023-11-30T09%3A12%3A35Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-29T19%3A09%3A56Z&ske=2023-11-30T19%3A09%3A56Z&sks=b&skv=2021-08-06&sig=86NN5ivULV4pkTti/xzNhd%2BCwyhKprF/F/0hOhKPojg%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-e5EImirvW6uwXmqoHccD1oT3/user-mdxGm7HSEajVtiHWLV0P3ZCJ/img-N8qSZjifrb0ZYwSGIBJbKmq4.png?st=2023-11-30T07%3A12%3A46Z&se=2023-11-30T09%3A12%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-29T19%3A10%3A33Z&ske=2023-11-30T19%3A10%3A33Z&sks=b&skv=2021-08-06&sig=Bcxe%2BqLArs8%2BvT0qNd4skXdv6TKjJEqaAblAYBnuNRg%3D
# ...
